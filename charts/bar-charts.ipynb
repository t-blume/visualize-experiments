# %%
import json
import os
import pickle
import gzip
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import tabulate
from tqdm import tqdm_notebook as tqdm

import numpy as np
from itertools import cycle, islice

# %%
fig_width = 6
fig_height = 5

params = {
    'axes.labelsize': 12, # fontsize for x and y labels (was 10)
    'axes.titlesize': 12,
    #'text.fontsize': 8, # was 10
    'legend.fontsize': 12, # was 10
    'xtick.labelsize': 12,
    'ytick.labelsize': 12,
    'text.usetex': False,
    'figure.figsize': [fig_width,fig_height],
    'font.family': 'serif',
    'grid.linestyle': '--',
}

matplotlib.rcParams.update(params)

# %%
data_dir = 'priv_data'
datasets =  ['timbl','dyldo']
bisimDepths = [0,1,2]
suffix = ''

model_dtype = pd.api.types.CategoricalDtype(categories=['Characteristic Sets', 'W-Property Clique',
                                                     'SemSets', 'SchemEX', 'TermPicker', 'SchemEX+U+oI',
                                                     'SchemEX+U+pI'], ordered=True)

# model_dtype = pd.api.types.CategoricalDtype(categories=['Model-A', 'Model-B',
#                                                     'Model-C', 'Model-D', 'Model-E', 'Model-F',
#                                                     'Model-G'], ordered=True)

config_dtype = pd.api.types.CategoricalDtype(categories=['SQ - 1k', 'SQ - 100k', 'SQ - 200k', 'CQ - 1k', 'CQ - 100k', 'SchemEX+U+oI',
                                                     'CQ - 200k'], ordered=True)

# %%
for dataset in datasets:
    for bisimK in bisimDepths:    
        # Load dataframe from CSV
        with open(os.path.join(data_dir, dataset +suffix + '.csv'), 'r') as f:
            df = pd.read_csv(f)
        df.head()
        # fig, ax = plt.subplots(figsize=(15,7))
        kf = df[df['k'] == bisimK]
        print(kf)
        kf['model'] = kf['model'].astype(model_dtype)
        kf['config'] = kf['config'].astype(config_dtype)
        ddf = kf.set_index(['model', 'config'])['f1']
        print(ddf)
        
        print('>>>>>>----------------')

        pdf = ddf.unstack()
        print(pdf)
        pdf = pdf.sort_values(by=['model'], axis=0, ascending=True)
        
        
        if bisimK != 0:
            plt.rcParams['figure.figsize'] = [fig_width,4]
        else:
            plt.rcParams['figure.figsize'] = [fig_width,5]
            
        ax = pdf.plot(kind='bar', color=['lightblue', 'c', 'b', 'rosybrown', 'firebrick', 'red'], width=.75, rot=45)
        ax.set_ylim([0,1])
        # ax.legend(plot_methods.values())
        # ax.set_xticklabels([f'({int(i.left)}, {int(i.right)}]' for i in bins.cat.categories])
        ax.set_xlabel("")
        ax.set_ylabel("")
        ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.4), shadow=True, ncol=3)
        
        if bisimK != 0:
            ax.get_legend().remove()
        
 
        plt.tight_layout()
        plt.grid()
        plt.savefig(dataset + '-'+ str(bisimK) + 'approx.pdf', bbox_inches='tight', format='pdf')
# Out:
#     k                model     config    f1
# 0   0  Characteristic Sets    SQ - 1k   NaN
# 1   0  Characteristic Sets  SQ - 100k   NaN
# 2   0  Characteristic Sets  SQ - 200k   NaN
# 3   0    W-Property Clique    SQ - 1k   NaN
# 4   0    W-Property Clique  SQ - 100k   NaN
# 5   0    W-Property Clique  SQ - 200k   NaN
# 6   0              SemSets    SQ - 1k  0.94
# 7   0              SemSets  SQ - 100k  0.97
# 8   0              SemSets  SQ - 200k  0.98
# 9   0              SchemEX    SQ - 1k  0.94
# 10  0              SchemEX  SQ - 100k  0.97
# 11  0              SchemEX  SQ - 200k  0.98
# 12  0           TermPicker    SQ - 1k  0.94
# 13  0           TermPicker  SQ - 100k  0.97
# 14  0           TermPicker  SQ - 200k  0.98
# 15  0         SchemEX+U+oI    SQ - 1k  0.85
# 16  0         SchemEX+U+oI  SQ - 100k  0.91
# 17  0         SchemEX+U+oI  SQ - 200k  0.93
# 18  0         SchemEX+U+pI    SQ - 1k  0.92
# 19  0         SchemEX+U+pI  SQ - 100k  0.97
# 20  0         SchemEX+U+pI  SQ - 200k  0.98
# 21  0  Characteristic Sets    CQ - 1k  0.00
# 22  0  Characteristic Sets  CQ - 100k  0.00
# 23  0  Characteristic Sets  CQ - 200k  0.00
# 24  0    W-Property Clique    CQ - 1k  0.00
# 25  0    W-Property Clique  CQ - 100k  0.00
# 26  0    W-Property Clique  CQ - 200k  0.00
# 27  0              SemSets    CQ - 1k   NaN
# 28  0              SemSets  CQ - 100k   NaN
# 29  0              SemSets  CQ - 200k   NaN
# 30  0              SchemEX    CQ - 1k   NaN
# 31  0              SchemEX  CQ - 100k   NaN
# 32  0              SchemEX  CQ - 200k   NaN
# 33  0           TermPicker    CQ - 1k   NaN
# 34  0           TermPicker  CQ - 100k   NaN
# 35  0           TermPicker  CQ - 200k   NaN
# 36  0         SchemEX+U+oI    CQ - 1k   NaN
# 37  0         SchemEX+U+oI  CQ - 100k   NaN
# 38  0         SchemEX+U+oI  CQ - 200k   NaN
# 39  0         SchemEX+U+pI    CQ - 1k   NaN
# 40  0         SchemEX+U+pI  CQ - 100k   NaN
# 41  0         SchemEX+U+pI  CQ - 200k   NaN
# model                config
# Characteristic Sets  SQ - 1k       NaN
#                      SQ - 100k     NaN
#                      SQ - 200k     NaN
# W-Property Clique    SQ - 1k       NaN
#                      SQ - 100k     NaN
#                      SQ - 200k     NaN
# SemSets              SQ - 1k      0.94
#                      SQ - 100k    0.97
#                      SQ - 200k    0.98
# SchemEX              SQ - 1k      0.94
#                      SQ - 100k    0.97
#                      SQ - 200k    0.98
# TermPicker           SQ - 1k      0.94
#                      SQ - 100k    0.97
#                      SQ - 200k    0.98
# SchemEX+U+oI         SQ - 1k      0.85
#                      SQ - 100k    0.91
#                      SQ - 200k    0.93
# SchemEX+U+pI         SQ - 1k      0.92
#                      SQ - 100k    0.97
#                      SQ - 200k    0.98
# Characteristic Sets  CQ - 1k      0.00
#                      CQ - 100k    0.00
#                      CQ - 200k    0.00
# W-Property Clique    CQ - 1k      0.00
#                      CQ - 100k    0.00
#                      CQ - 200k    0.00
# SemSets              CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# SchemEX              CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# TermPicker           CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# SchemEX+U+oI         CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# SchemEX+U+pI         CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# Name: f1, dtype: float64
# >>>>>>----------------
# config               SQ - 1k  SQ - 100k  SQ - 200k  CQ - 1k  CQ - 100k  \
# model
# Characteristic Sets      NaN        NaN        NaN      0.0        0.0
# W-Property Clique        NaN        NaN        NaN      0.0        0.0
# SemSets                 0.94       0.97       0.98      NaN        NaN
# SchemEX                 0.94       0.97       0.98      NaN        NaN
# TermPicker              0.94       0.97       0.98      NaN        NaN
# SchemEX+U+oI            0.85       0.91       0.93      NaN        NaN
# SchemEX+U+pI            0.92       0.97       0.98      NaN        NaN
#
# config               CQ - 200k
# model
# Characteristic Sets        0.0
# W-Property Clique          0.0
# SemSets                    NaN
# SchemEX                    NaN
# TermPicker                 NaN
# SchemEX+U+oI               NaN
# SchemEX+U+pI               NaN
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#     k                model     config    f1
# 42  1  Characteristic Sets    SQ - 1k   NaN
# 43  1  Characteristic Sets  SQ - 100k   NaN
# 44  1  Characteristic Sets  SQ - 200k   NaN
# 45  1    W-Property Clique    SQ - 1k   NaN
# 46  1    W-Property Clique  SQ - 100k   NaN
# 47  1    W-Property Clique  SQ - 200k   NaN
# 48  1              SemSets    SQ - 1k  0.73
# 49  1              SemSets  SQ - 100k  0.76
# 50  1              SemSets  SQ - 200k  0.76
# 51  1              SchemEX    SQ - 1k  0.73
# 52  1              SchemEX  SQ - 100k  0.75
# 53  1              SchemEX  SQ - 200k  0.76
# 54  1           TermPicker    SQ - 1k  0.22
# 55  1           TermPicker  SQ - 100k  0.25
# 56  1           TermPicker  SQ - 200k  0.29
# 57  1         SchemEX+U+oI    SQ - 1k  0.65
# 58  1         SchemEX+U+oI  SQ - 100k  0.70
# 59  1         SchemEX+U+oI  SQ - 200k  0.71
# 60  1         SchemEX+U+pI    SQ - 1k  0.80
# 61  1         SchemEX+U+pI  SQ - 100k  0.80
# 62  1         SchemEX+U+pI  SQ - 200k  0.85
# 63  1  Characteristic Sets    CQ - 1k  0.60
# 64  1  Characteristic Sets  CQ - 100k  0.77
# 65  1  Characteristic Sets  CQ - 200k  0.78
# 66  1    W-Property Clique    CQ - 1k  0.76
# 67  1    W-Property Clique  CQ - 100k  0.76
# 68  1    W-Property Clique  CQ - 200k  0.76
# 69  1              SemSets    CQ - 1k  0.39
# 70  1              SemSets  CQ - 100k  0.44
# 71  1              SemSets  CQ - 200k  0.44
# 72  1              SchemEX    CQ - 1k  0.39
# 73  1              SchemEX  CQ - 100k  0.44
# 74  1              SchemEX  CQ - 200k  0.46
# 75  1           TermPicker    CQ - 1k  0.14
# 76  1           TermPicker  CQ - 100k  0.23
# 77  1           TermPicker  CQ - 200k  0.29
# 78  1         SchemEX+U+oI    CQ - 1k  0.33
# 79  1         SchemEX+U+oI  CQ - 100k  0.42
# 80  1         SchemEX+U+oI  CQ - 200k  0.45
# 81  1         SchemEX+U+pI    CQ - 1k  0.49
# 82  1         SchemEX+U+pI  CQ - 100k  0.50
# 83  1         SchemEX+U+pI  CQ - 200k  0.65
# model                config
# Characteristic Sets  SQ - 1k       NaN
#                      SQ - 100k     NaN
#                      SQ - 200k     NaN
# W-Property Clique    SQ - 1k       NaN
#                      SQ - 100k     NaN
#                      SQ - 200k     NaN
# SemSets              SQ - 1k      0.73
#                      SQ - 100k    0.76
#                      SQ - 200k    0.76
# SchemEX              SQ - 1k      0.73
#                      SQ - 100k    0.75
#                      SQ - 200k    0.76
# TermPicker           SQ - 1k      0.22
#                      SQ - 100k    0.25
#                      SQ - 200k    0.29
# SchemEX+U+oI         SQ - 1k      0.65
#                      SQ - 100k    0.70
#                      SQ - 200k    0.71
# SchemEX+U+pI         SQ - 1k      0.80
#                      SQ - 100k    0.80
#                      SQ - 200k    0.85
# Characteristic Sets  CQ - 1k      0.60
#                      CQ - 100k    0.77
#                      CQ - 200k    0.78
# W-Property Clique    CQ - 1k      0.76
#                      CQ - 100k    0.76
#                      CQ - 200k    0.76
# SemSets              CQ - 1k      0.39
#                      CQ - 100k    0.44
#                      CQ - 200k    0.44
# SchemEX              CQ - 1k      0.39
#                      CQ - 100k    0.44
#                      CQ - 200k    0.46
# TermPicker           CQ - 1k      0.14
#                      CQ - 100k    0.23
#                      CQ - 200k    0.29
# SchemEX+U+oI         CQ - 1k      0.33
#                      CQ - 100k    0.42
#                      CQ - 200k    0.45
# SchemEX+U+pI         CQ - 1k      0.49
#                      CQ - 100k    0.50
#                      CQ - 200k    0.65
# Name: f1, dtype: float64
# >>>>>>----------------
# config               SQ - 1k  SQ - 100k  SQ - 200k  CQ - 1k  CQ - 100k  \
# model
# Characteristic Sets      NaN        NaN        NaN     0.60       0.77
# W-Property Clique        NaN        NaN        NaN     0.76       0.76
# SemSets                 0.73       0.76       0.76     0.39       0.44
# SchemEX                 0.73       0.75       0.76     0.39       0.44
# TermPicker              0.22       0.25       0.29     0.14       0.23
# SchemEX+U+oI            0.65       0.70       0.71     0.33       0.42
# SchemEX+U+pI            0.80       0.80       0.85     0.49       0.50
#
# config               CQ - 200k
# model
# Characteristic Sets       0.78
# W-Property Clique         0.76
# SemSets                   0.44
# SchemEX                   0.46
# TermPicker                0.29
# SchemEX+U+oI              0.45
# SchemEX+U+pI              0.65
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#      k                model     config    f1
# 84   2  Characteristic Sets    SQ - 1k   NaN
# 85   2  Characteristic Sets  SQ - 100k   NaN
# 86   2  Characteristic Sets  SQ - 200k   NaN
# 87   2    W-Property Clique    SQ - 1k   NaN
# 88   2    W-Property Clique  SQ - 100k   NaN
# 89   2    W-Property Clique  SQ - 200k   NaN
# 90   2              SemSets    SQ - 1k  0.71
# 91   2              SemSets  SQ - 100k  0.78
# 92   2              SemSets  SQ - 200k  0.78
# 93   2              SchemEX    SQ - 1k  0.59
# 94   2              SchemEX  SQ - 100k  0.77
# 95   2              SchemEX  SQ - 200k  0.78
# 96   2           TermPicker    SQ - 1k  0.19
# 97   2           TermPicker  SQ - 100k  0.21
# 98   2           TermPicker  SQ - 200k  0.24
# 99   2         SchemEX+U+oI    SQ - 1k  0.41
# 100  2         SchemEX+U+oI  SQ - 100k  0.69
# 101  2         SchemEX+U+oI  SQ - 200k  0.70
# 102  2         SchemEX+U+pI    SQ - 1k  0.67
# 103  2         SchemEX+U+pI  SQ - 100k  0.73
# 104  2         SchemEX+U+pI  SQ - 200k  0.74
# 105  2  Characteristic Sets    CQ - 1k  0.04
# 106  2  Characteristic Sets  CQ - 100k  0.18
# 107  2  Characteristic Sets  CQ - 200k  0.21
# 108  2    W-Property Clique    CQ - 1k  0.42
# 109  2    W-Property Clique  CQ - 100k  0.44
# 110  2    W-Property Clique  CQ - 200k  0.45
# 111  2              SemSets    CQ - 1k  0.26
# 112  2              SemSets  CQ - 100k  0.32
# 113  2              SemSets  CQ - 200k  0.33
# 114  2              SchemEX    CQ - 1k  0.11
# 115  2              SchemEX  CQ - 100k  0.24
# 116  2              SchemEX  CQ - 200k  0.26
# 117  2           TermPicker    CQ - 1k  0.04
# 118  2           TermPicker  CQ - 100k  0.05
# 119  2           TermPicker  CQ - 200k  0.07
# 120  2         SchemEX+U+oI    CQ - 1k  0.06
# 121  2         SchemEX+U+oI  CQ - 100k  0.18
# 122  2         SchemEX+U+oI  CQ - 200k  0.19
# 123  2         SchemEX+U+pI    CQ - 1k  0.16
# 124  2         SchemEX+U+pI  CQ - 100k  0.22
# 125  2         SchemEX+U+pI  CQ - 200k  0.23
# model                config
# Characteristic Sets  SQ - 1k       NaN
#                      SQ - 100k     NaN
#                      SQ - 200k     NaN
# W-Property Clique    SQ - 1k       NaN
#                      SQ - 100k     NaN
#                      SQ - 200k     NaN
# SemSets              SQ - 1k      0.71
#                      SQ - 100k    0.78
#                      SQ - 200k    0.78
# SchemEX              SQ - 1k      0.59
#                      SQ - 100k    0.77
#                      SQ - 200k    0.78
# TermPicker           SQ - 1k      0.19
#                      SQ - 100k    0.21
#                      SQ - 200k    0.24
# SchemEX+U+oI         SQ - 1k      0.41
#                      SQ - 100k    0.69
#                      SQ - 200k    0.70
# SchemEX+U+pI         SQ - 1k      0.67
#                      SQ - 100k    0.73
#                      SQ - 200k    0.74
# Characteristic Sets  CQ - 1k      0.04
#                      CQ - 100k    0.18
#                      CQ - 200k    0.21
# W-Property Clique    CQ - 1k      0.42
#                      CQ - 100k    0.44
#                      CQ - 200k    0.45
# SemSets              CQ - 1k      0.26
#                      CQ - 100k    0.32
#                      CQ - 200k    0.33
# SchemEX              CQ - 1k      0.11
#                      CQ - 100k    0.24
#                      CQ - 200k    0.26
# TermPicker           CQ - 1k      0.04
#                      CQ - 100k    0.05
#                      CQ - 200k    0.07
# SchemEX+U+oI         CQ - 1k      0.06
#                      CQ - 100k    0.18
#                      CQ - 200k    0.19
# SchemEX+U+pI         CQ - 1k      0.16
#                      CQ - 100k    0.22
#                      CQ - 200k    0.23
# Name: f1, dtype: float64
# >>>>>>----------------
# config               SQ - 1k  SQ - 100k  SQ - 200k  CQ - 1k  CQ - 100k  \
# model
# Characteristic Sets      NaN        NaN        NaN     0.04       0.18
# W-Property Clique        NaN        NaN        NaN     0.42       0.44
# SemSets                 0.71       0.78       0.78     0.26       0.32
# SchemEX                 0.59       0.77       0.78     0.11       0.24
# TermPicker              0.19       0.21       0.24     0.04       0.05
# SchemEX+U+oI            0.41       0.69       0.70     0.06       0.18
# SchemEX+U+pI            0.67       0.73       0.74     0.16       0.22
#
# config               CQ - 200k
# model
# Characteristic Sets       0.21
# W-Property Clique         0.45
# SemSets                   0.33
# SchemEX                   0.26
# TermPicker                0.07
# SchemEX+U+oI              0.19
# SchemEX+U+pI              0.23
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#     k                model     config    f1
# 0   0  Characteristic Sets    SQ - 1k  0.00
# 1   0  Characteristic Sets  SQ - 100k  0.00
# 2   0  Characteristic Sets  SQ - 200k  0.00
# 3   0    W-Property Clique    SQ - 1k  0.00
# 4   0    W-Property Clique  SQ - 100k  0.00
# 5   0    W-Property Clique  SQ - 200k  0.00
# 6   0              SemSets    SQ - 1k  0.56
# 7   0              SemSets  SQ - 100k  0.57
# 8   0              SemSets  SQ - 200k  0.58
# 9   0              SchemEX    SQ - 1k  0.56
# 10  0              SchemEX  SQ - 100k  0.57
# 11  0              SchemEX  SQ - 200k  0.58
# 12  0           TermPicker    SQ - 1k  0.56
# 13  0           TermPicker  SQ - 100k  0.57
# 14  0           TermPicker  SQ - 200k  0.58
# 15  0         SchemEX+U+oI    SQ - 1k  0.44
# 16  0         SchemEX+U+oI  SQ - 100k  0.47
# 17  0         SchemEX+U+oI  SQ - 200k  0.47
# 18  0         SchemEX+U+pI    SQ - 1k  0.57
# 19  0         SchemEX+U+pI  SQ - 100k  0.59
# 20  0         SchemEX+U+pI  SQ - 200k  0.60
# 21  0  Characteristic Sets    CQ - 1k  0.00
# 22  0  Characteristic Sets  CQ - 100k  0.00
# 23  0  Characteristic Sets  CQ - 200k  0.00
# 24  0    W-Property Clique    CQ - 1k  0.00
# 25  0    W-Property Clique  CQ - 100k  0.00
# 26  0    W-Property Clique  CQ - 200k  0.00
# 27  0              SemSets    CQ - 1k   NaN
# 28  0              SemSets  CQ - 100k   NaN
# 29  0              SemSets  CQ - 200k   NaN
# 30  0              SchemEX    CQ - 1k   NaN
# 31  0              SchemEX  CQ - 100k   NaN
# 32  0              SchemEX  CQ - 200k   NaN
# 33  0           TermPicker    CQ - 1k   NaN
# 34  0           TermPicker  CQ - 100k   NaN
# 35  0           TermPicker  CQ - 200k   NaN
# 36  0         SchemEX+U+oI    CQ - 1k   NaN
# 37  0         SchemEX+U+oI  CQ - 100k   NaN
# 38  0         SchemEX+U+oI  CQ - 200k   NaN
# 39  0         SchemEX+U+pI    CQ - 1k   NaN
# 40  0         SchemEX+U+pI  CQ - 100k   NaN
# 41  0         SchemEX+U+pI  CQ - 200k   NaN
# model                config
# Characteristic Sets  SQ - 1k      0.00
#                      SQ - 100k    0.00
#                      SQ - 200k    0.00
# W-Property Clique    SQ - 1k      0.00
#                      SQ - 100k    0.00
#                      SQ - 200k    0.00
# SemSets              SQ - 1k      0.56
#                      SQ - 100k    0.57
#                      SQ - 200k    0.58
# SchemEX              SQ - 1k      0.56
#                      SQ - 100k    0.57
#                      SQ - 200k    0.58
# TermPicker           SQ - 1k      0.56
#                      SQ - 100k    0.57
#                      SQ - 200k    0.58
# SchemEX+U+oI         SQ - 1k      0.44
#                      SQ - 100k    0.47
#                      SQ - 200k    0.47
# SchemEX+U+pI         SQ - 1k      0.57
#                      SQ - 100k    0.59
#                      SQ - 200k    0.60
# Characteristic Sets  CQ - 1k      0.00
#                      CQ - 100k    0.00
#                      CQ - 200k    0.00
# W-Property Clique    CQ - 1k      0.00
#                      CQ - 100k    0.00
#                      CQ - 200k    0.00
# SemSets              CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# SchemEX              CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# TermPicker           CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# SchemEX+U+oI         CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# SchemEX+U+pI         CQ - 1k       NaN
#                      CQ - 100k     NaN
#                      CQ - 200k     NaN
# Name: f1, dtype: float64
# >>>>>>----------------
# config               SQ - 1k  SQ - 100k  SQ - 200k  CQ - 1k  CQ - 100k  \
# model
# Characteristic Sets     0.00       0.00       0.00      0.0        0.0
# W-Property Clique       0.00       0.00       0.00      0.0        0.0
# SemSets                 0.56       0.57       0.58      NaN        NaN
# SchemEX                 0.56       0.57       0.58      NaN        NaN
# TermPicker              0.56       0.57       0.58      NaN        NaN
# SchemEX+U+oI            0.44       0.47       0.47      NaN        NaN
# SchemEX+U+pI            0.57       0.59       0.60      NaN        NaN
#
# config               CQ - 200k
# model
# Characteristic Sets        0.0
# W-Property Clique          0.0
# SemSets                    NaN
# SchemEX                    NaN
# TermPicker                 NaN
# SchemEX+U+oI               NaN
# SchemEX+U+pI               NaN
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#     k                model     config    f1
# 42  1  Characteristic Sets    SQ - 1k  0.00
# 43  1  Characteristic Sets  SQ - 100k  0.00
# 44  1  Characteristic Sets  SQ - 200k  0.00
# 45  1    W-Property Clique    SQ - 1k  0.00
# 46  1    W-Property Clique  SQ - 100k  0.00
# 47  1    W-Property Clique  SQ - 200k  0.00
# 48  1              SemSets    SQ - 1k  0.49
# 49  1              SemSets  SQ - 100k  0.50
# 50  1              SemSets  SQ - 200k  0.50
# 51  1              SchemEX    SQ - 1k  0.49
# 52  1              SchemEX  SQ - 100k  0.50
# 53  1              SchemEX  SQ - 200k  0.50
# 54  1           TermPicker    SQ - 1k  0.36
# 55  1           TermPicker  SQ - 100k  0.37
# 56  1           TermPicker  SQ - 200k  0.37
# 57  1         SchemEX+U+oI    SQ - 1k  0.41
# 58  1         SchemEX+U+oI  SQ - 100k  0.43
# 59  1         SchemEX+U+oI  SQ - 200k  0.43
# 60  1         SchemEX+U+pI    SQ - 1k  0.88
# 61  1         SchemEX+U+pI  SQ - 100k  0.89
# 62  1         SchemEX+U+pI  SQ - 200k  0.91
# 63  1  Characteristic Sets    CQ - 1k  0.68
# 64  1  Characteristic Sets  CQ - 100k  0.71
# 65  1  Characteristic Sets  CQ - 200k  0.72
# 66  1    W-Property Clique    CQ - 1k  0.89
# 67  1    W-Property Clique  CQ - 100k  0.92
# 68  1    W-Property Clique  CQ - 200k  0.89
# 69  1              SemSets    CQ - 1k  0.31
# 70  1              SemSets  CQ - 100k  0.32
# 71  1              SemSets  CQ - 200k  0.33
# 72  1              SchemEX    CQ - 1k  0.16
# 73  1              SchemEX  CQ - 100k  0.17
# 74  1              SchemEX  CQ - 200k  0.18
# 75  1           TermPicker    CQ - 1k  0.12
# 76  1           TermPicker  CQ - 100k  0.14
# 77  1           TermPicker  CQ - 200k  0.15
# 78  1         SchemEX+U+oI    CQ - 1k  0.13
# 79  1         SchemEX+U+oI  CQ - 100k  0.13
# 80  1         SchemEX+U+oI  CQ - 200k  0.14
# 81  1         SchemEX+U+pI    CQ - 1k  0.39
# 82  1         SchemEX+U+pI  CQ - 100k  0.41
# 83  1         SchemEX+U+pI  CQ - 200k  0.43
# model                config
# Characteristic Sets  SQ - 1k      0.00
#                      SQ - 100k    0.00
#                      SQ - 200k    0.00
# W-Property Clique    SQ - 1k      0.00
#                      SQ - 100k    0.00
#                      SQ - 200k    0.00
# SemSets              SQ - 1k      0.49
#                      SQ - 100k    0.50
#                      SQ - 200k    0.50
# SchemEX              SQ - 1k      0.49
#                      SQ - 100k    0.50
#                      SQ - 200k    0.50
# TermPicker           SQ - 1k      0.36
#                      SQ - 100k    0.37
#                      SQ - 200k    0.37
# SchemEX+U+oI         SQ - 1k      0.41
#                      SQ - 100k    0.43
#                      SQ - 200k    0.43
# SchemEX+U+pI         SQ - 1k      0.88
#                      SQ - 100k    0.89
#                      SQ - 200k    0.91
# Characteristic Sets  CQ - 1k      0.68
#                      CQ - 100k    0.71
#                      CQ - 200k    0.72
# W-Property Clique    CQ - 1k      0.89
#                      CQ - 100k    0.92
#                      CQ - 200k    0.89
# SemSets              CQ - 1k      0.31
#                      CQ - 100k    0.32
#                      CQ - 200k    0.33
# SchemEX              CQ - 1k      0.16
#                      CQ - 100k    0.17
#                      CQ - 200k    0.18
# TermPicker           CQ - 1k      0.12
#                      CQ - 100k    0.14
#                      CQ - 200k    0.15
# SchemEX+U+oI         CQ - 1k      0.13
#                      CQ - 100k    0.13
#                      CQ - 200k    0.14
# SchemEX+U+pI         CQ - 1k      0.39
#                      CQ - 100k    0.41
#                      CQ - 200k    0.43
# Name: f1, dtype: float64
# >>>>>>----------------
# config               SQ - 1k  SQ - 100k  SQ - 200k  CQ - 1k  CQ - 100k  \
# model
# Characteristic Sets     0.00       0.00       0.00     0.68       0.71
# W-Property Clique       0.00       0.00       0.00     0.89       0.92
# SemSets                 0.49       0.50       0.50     0.31       0.32
# SchemEX                 0.49       0.50       0.50     0.16       0.17
# TermPicker              0.36       0.37       0.37     0.12       0.14
# SchemEX+U+oI            0.41       0.43       0.43     0.13       0.13
# SchemEX+U+pI            0.88       0.89       0.91     0.39       0.41
#
# config               CQ - 200k
# model
# Characteristic Sets       0.72
# W-Property Clique         0.89
# SemSets                   0.33
# SchemEX                   0.18
# TermPicker                0.15
# SchemEX+U+oI              0.14
# SchemEX+U+pI              0.43
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#      k                model     config    f1
# 84   2  Characteristic Sets    SQ - 1k  0.00
# 85   2  Characteristic Sets  SQ - 100k  0.00
# 86   2  Characteristic Sets  SQ - 200k  0.00
# 87   2    W-Property Clique    SQ - 1k  0.00
# 88   2    W-Property Clique  SQ - 100k  0.00
# 89   2    W-Property Clique  SQ - 200k  0.00
# 90   2              SemSets    SQ - 1k  0.49
# 91   2              SemSets  SQ - 100k  0.50
# 92   2              SemSets  SQ - 200k  0.50
# 93   2              SchemEX    SQ - 1k  0.49
# 94   2              SchemEX  SQ - 100k  0.49
# 95   2              SchemEX  SQ - 200k  0.50
# 96   2           TermPicker    SQ - 1k  0.35
# 97   2           TermPicker  SQ - 100k  0.36
# 98   2           TermPicker  SQ - 200k  0.36
# 99   2         SchemEX+U+oI    SQ - 1k  0.41
# 100  2         SchemEX+U+oI  SQ - 100k  0.43
# 101  2         SchemEX+U+oI  SQ - 200k  0.43
# 102  2         SchemEX+U+pI    SQ - 1k  0.57
# 103  2         SchemEX+U+pI  SQ - 100k  0.59
# 104  2         SchemEX+U+pI  SQ - 200k  0.60
# 105  2  Characteristic Sets    CQ - 1k  0.03
# 106  2  Characteristic Sets  CQ - 100k  0.13
# 107  2  Characteristic Sets  CQ - 200k  0.15
# 108  2    W-Property Clique    CQ - 1k  0.51
# 109  2    W-Property Clique  CQ - 100k  0.58
# 110  2    W-Property Clique  CQ - 200k  0.58
# 111  2              SemSets    CQ - 1k  0.23
# 112  2              SemSets  CQ - 100k  0.25
# 113  2              SemSets  CQ - 200k  0.25
# 114  2              SchemEX    CQ - 1k  0.08
# 115  2              SchemEX  CQ - 100k  0.09
# 116  2              SchemEX  CQ - 200k  0.09
# 117  2           TermPicker    CQ - 1k  0.04
# 118  2           TermPicker  CQ - 100k  0.04
# 119  2           TermPicker  CQ - 200k  0.04
# 120  2         SchemEX+U+oI    CQ - 1k  0.06
# 121  2         SchemEX+U+oI  CQ - 100k  0.07
# 122  2         SchemEX+U+oI  CQ - 200k  0.08
# 123  2         SchemEX+U+pI    CQ - 1k  0.07
# 124  2         SchemEX+U+pI  CQ - 100k  0.08
# 125  2         SchemEX+U+pI  CQ - 200k  0.09
# model                config
# Characteristic Sets  SQ - 1k      0.00
#                      SQ - 100k    0.00
#                      SQ - 200k    0.00
# W-Property Clique    SQ - 1k      0.00
#                      SQ - 100k    0.00
#                      SQ - 200k    0.00
# SemSets              SQ - 1k      0.49
#                      SQ - 100k    0.50
#                      SQ - 200k    0.50
# SchemEX              SQ - 1k      0.49
#                      SQ - 100k    0.49
#                      SQ - 200k    0.50
# TermPicker           SQ - 1k      0.35
#                      SQ - 100k    0.36
#                      SQ - 200k    0.36
# SchemEX+U+oI         SQ - 1k      0.41
#                      SQ - 100k    0.43
#                      SQ - 200k    0.43
# SchemEX+U+pI         SQ - 1k      0.57
#                      SQ - 100k    0.59
#                      SQ - 200k    0.60
# Characteristic Sets  CQ - 1k      0.03
#                      CQ - 100k    0.13
#                      CQ - 200k    0.15
# W-Property Clique    CQ - 1k      0.51
#                      CQ - 100k    0.58
#                      CQ - 200k    0.58
# SemSets              CQ - 1k      0.23
#                      CQ - 100k    0.25
#                      CQ - 200k    0.25
# SchemEX              CQ - 1k      0.08
#                      CQ - 100k    0.09
#                      CQ - 200k    0.09
# TermPicker           CQ - 1k      0.04
#                      CQ - 100k    0.04
#                      CQ - 200k    0.04
# SchemEX+U+oI         CQ - 1k      0.06
#                      CQ - 100k    0.07
#                      CQ - 200k    0.08
# SchemEX+U+pI         CQ - 1k      0.07
#                      CQ - 100k    0.08
#                      CQ - 200k    0.09
# Name: f1, dtype: float64
# >>>>>>----------------
# config               SQ - 1k  SQ - 100k  SQ - 200k  CQ - 1k  CQ - 100k  \
# model
# Characteristic Sets     0.00       0.00       0.00     0.03       0.13
# W-Property Clique       0.00       0.00       0.00     0.51       0.58
# SemSets                 0.49       0.50       0.50     0.23       0.25
# SchemEX                 0.49       0.49       0.50     0.08       0.09
# TermPicker              0.35       0.36       0.36     0.04       0.04
# SchemEX+U+oI            0.41       0.43       0.43     0.06       0.07
# SchemEX+U+pI            0.57       0.59       0.60     0.07       0.08
#
# config               CQ - 200k
# model
# Characteristic Sets       0.15
# W-Property Clique         0.58
# SemSets                   0.25
# SchemEX                   0.09
# TermPicker                0.04
# SchemEX+U+oI              0.08
# SchemEX+U+pI              0.09
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /home/till/GIT/visualize-experiments/charts/env/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
